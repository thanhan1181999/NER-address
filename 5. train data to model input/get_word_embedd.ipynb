# %%
# !pip install git+https://github.com/facebookresearch/fastText.git
# Out:
# ...
#   Cloning https://github.com/facebookresearch/fastText.git to /tmp/pip-req-build-z8cowbto
#   Running command git clone -q https://github.com/facebookresearch/fastText.git /tmp/pip-req-build-z8cowbto
# ...
#   Created wheel for fasttext: filename=fasttext-0.9.2-cp37-cp37m-linux_x86_64.whl size=3091292 sha256=696eec2e12d17ba61a659e8cb4cec20cea5c6697700511d5d9f1aa3d08339d01
#   Stored in directory: /tmp/pip-ephem-wheel-cache-a7w81vnv/wheels/69/f8/19/7f0ab407c078795bc9f86e1f6381349254f86fd7d229902355
# Successfully built fasttext
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#get word embedding libary
import fasttext.util
print('Creating fastText...')
word2vec = fasttext.load_model('/content/drive/MyDrive/fast_text/cc.vi.300.bin')
print('fastText created!')
# Out:
# Creating fastText...
# fastText created!

# %%
# !pip install SciPy

# %%
# from scipy import spatial

# %%
# def simility(a,b):
#   return 1 - spatial.distance.cosine(a, b)

# %%
#  query = "nhà hàng"
#  a = word2vec.get_word_vector(query).tolist()
#  query = "ngân hàng"
# #  query = "ăn uống"
#  b = word2vec.get_word_vector(query).tolist()
#  print(simility(a, b))

# %%
import re
def map_number_and_punct(word):
    # check hem va ngach
    num_of_seperate=0
    dem=0
    for char in word:
      if not char.isnumeric() and char!="/":
        dem+=1        
      if char=="/":
        num_of_seperate+=1
    if dem==0:
      if len(word)>1 and num_of_seperate==1:
        return u'<ngach>'
      if len(word)>1 and num_of_seperate>1:
        return u'<hem>'

    # if re.match(r"^[0-9]{2}0{3}$", word):
    #     return u'<postcode>'
    
    if word.isnumeric():
        word = u'<number>'
    elif word in [u',', u'<', u'.', u'>', u'/', u'?', u'..', u'...', u'....', u':', u';', u'"', u"'", u'[', u'{', u']',
                  u'}', u'|', u'\\', u'`', u'~', u'!', u'@', u'#', u'$', u'%', u'^', u'&', u'*', u'(', u')', u'-', u'+',
                  u'=']:
        word = u'<punct>'

    # word = word.replace("_"," ")
    
    return word

# %%
import numpy as np
import codecs
def read_data(input_file):
    with codecs.open(input_file, 'r', 'utf-8') as f:
        word_list = [] 
        words = []
        for line in f:
            line = line.split()
            if len(line) > 0:
                words.append( map_number_and_punct(line[0].lower()) )
            else:
                word_list.append(words)
                words = []
    return word_list

# %%
val_word_sentences = read_data('/content/drive/MyDrive/fast_text/val/data_no_tag.txt')
val_output = '/content/drive/MyDrive/fast_text/val/word_embedd.txt'
print(len(val_word_sentences))
train_word_sentences = read_data('/content/drive/MyDrive/fast_text/train/data_no_tag.txt')
train_output = '/content/drive/MyDrive/fast_text/train/word_embedd.txt'
print(len(train_word_sentences))
test_word_sentences = read_data('/content/drive/MyDrive/fast_text/test/data_no_tag_pre.txt')
test_output = '/content/drive/MyDrive/fast_text/test/word_embedd.txt'
print(len(test_word_sentences))
# Out:
# 450
# 3147
# 900

# %%
def construct_tensor_word(word_sentences, unknown_embedd, embedd_dim, max_length,ouput_file):
    fileout = open(ouput_file, 'a+', encoding='utf8')
    X = np.empty([1, max_length, embedd_dim])
    for i in range(len(word_sentences)):
        words = word_sentences[i] # words is a sentence
        print("=====sentence "+str(i)+" ==========")
        length = len(words)
        # run through all word in a sentence
        for j in range(length):
            word = words[j].lower()
            while True:
                try:
                    embedd = word2vec.get_word_vector(query).tolist()
                    embedd = np.ones([1, embedd_dim])
                    break
                except:
                    embedd = unknown_embedd[0]
                    break         
            X[0, j, :] = embedd

        X[0, length:] = np.zeros([1, embedd_dim])
        print(X.shape)

        np.savetxt(fileout, X[0])
    fileout.close()
    return X

# %%
unknown_embedd = np.random.uniform(-0.01, 0.01, [1, 300])

word_train = construct_tensor_word(train_word_sentences, unknown_embedd, 300, 42,train_output)

word_val = construct_tensor_word(val_word_sentences, unknown_embedd, 300, 42,val_output)

word_test = construct_tensor_word(test_word_sentences, unknown_embedd, 300, 42, test_output)
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
# =====sentence 1997 ==========
# (1, 42, 300)
# =====sentence 1998 ==========
# (1, 42, 300)
# =====sentence 1999 ==========
# (1, 42, 300)
# =====sentence 2000 ==========
# (1, 42, 300)
# =====sentence 2001 ==========
# (1, 42, 300)
# =====sentence 2002 ==========
# (1, 42, 300)
# =====sentence 2003 ==========
# (1, 42, 300)
# =====sentence 2004 ==========
# (1, 42, 300)
# =====sentence 2005 ==========
# (1, 42, 300)
# =====sentence 2006 ==========
# (1, 42, 300)
# =====sentence 2007 ==========
# (1, 42, 300)
# =====sentence 2008 ==========
# (1, 42, 300)
# =====sentence 2009 ==========
# (1, 42, 300)
# =====sentence 2010 ==========
# (1, 42, 300)
# =====sentence 2011 ==========
# (1, 42, 300)
# =====sentence 2012 ==========
# (1, 42, 300)
# =====sentence 2013 ==========
# (1, 42, 300)
# =====sentence 2014 ==========
# (1, 42, 300)
# =====sentence 2015 ==========
# (1, 42, 300)
# =====sentence 2016 ==========
# (1, 42, 300)
# ...
